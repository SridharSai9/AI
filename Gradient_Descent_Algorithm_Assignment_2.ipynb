# %% [markdown]
# <a href="https://colab.research.google.com/github/SridharSai9/AI/blob/main/Gradient_Descent_Algorithm_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Assignmemt 2 .jpg](data:image/jpeg;base64,...)

# %%
import numpy as n
import math as m
x=n.random.uniform(-10,10)
eta=0.01
max=100
i=0
while i<max:
  x_slope=4*m.pow(x,3)+6*x
  x_step_length=-eta*x_slope
  x=x+x_step_length
  i=i+1
min_value=m.pow(x,4)+3*m.pow(x,2)+10
print("Minimum value of objective function at x =",x,"is",min_value)
# Out:
# Minimum value of objective function at x = -0.0018064910634042748 is 10.000009790240536
